# %%
#1
class Marks:
  def __init__(self,mark):
    self.mark=mark
  def __add__(self,other):
    total=self.mark+other.mark
    return Marks(total)
Q1 = Marks(int(input("Quiz 1 (out of 10): ")))
Q2 = Marks(int(input("Quiz 2 (out of 10): ")))
Lab = Marks(int(input("Lab (out of 30): ")))
Mid = Marks(int(input("Mid (out of 20): ")))
Final = Marks(int(input("Final (out of 30): ")))
total = Q1 + Q2 + Lab + Mid + Final
print("Total marks: {}".format(total.mark))
# Out:
# Quiz 1 (out of 10): 10
# Quiz 2 (out of 10): 10
# Lab (out of 30): 30
# Mid (out of 20): 20
# Final (out of 30): 30
# Total marks: 100

# %%
#2
class Teacher:
  def __init__(self,name,dept):
    self.__name=name
    self.__dept=dept
    self.__list1=[]
  def addCourse(self,obj):
    self.__list1.append(obj.course_name)
  def printDetail(self):
    print(f"====================================\nName: {self.__name}\nDepartment: {self.__dept}\nList of courses\n====================================")
    for i in self.__list1:
      print(i)
    print("====================================") 


class Course:
  def __init__(self,name):
    self.course_name=name

t1 = Teacher("Saad Abdullah", "CSE")
t2 = Teacher("Mumit Khan", "CSE")
t3 = Teacher("Sadia Kazi", "CSE")                          
c1 = Course("CSE 110 Programming Language I")                           
c2 = Course("CSE 111 Programming Language-II")                           
c3 = Course("CSE 220 Data Structures")                           
c4 = Course("CSE 221 Algorithms")                           
c5 = Course("CCSE 230 Discrete Mathematics")                           
c6 = Course("CSE 310 Object Oriented Programming")                           
c7 = Course("CSE 320 Data Communications")                          
c8 = Course("CSE 340 Computer Architecture") 
t1.addCourse(c1)
t1.addCourse(c2)
t2.addCourse(c3)
t2.addCourse(c4)
t2.addCourse(c5)
t3.addCourse(c6)
t3.addCourse(c7)
t3.addCourse(c8)
t1.printDetail()
t2.printDetail()
t3.printDetail()
# Out:
# ...
# Name: Saad Abdullah
# Department: CSE
# List of courses
# ...
# CSE 110 Programming Language I
# CSE 111 Programming Language-II
# ...
# Name: Mumit Khan
# Department: CSE
# List of courses
# ...
# CSE 220 Data Structures
# CSE 221 Algorithms
# CCSE 230 Discrete Mathematics
# ...
# Name: Sadia Kazi
# Department: CSE
# List of courses
# ...
# CSE 310 Object Oriented Programming
# CSE 320 Data Communications
# CSE 340 Computer Architecture
# ...

# %%
#3
class Team:
  def __init__(self,tm_name=None):
     self.__tm_name=tm_name
     self.__list1=[]
  def __setName(self,change):
    self.__tm_name=change
class Player:
  def __init__(self,player):
    self.player=player
    self.list2=[]
    self.list2.append(player)
  def addPlayer(self,play):
    
  def printDetail(self):
    print(f"Name:{self.__tm_name}")

# %%
#4
class Color:
  def __init__(self,clr):
    self.clr=clr
    self.dict1={"redyellow":"Orange","redblue":"Violet","yellowblue":"Green"}
  def __add__(self,other):
    for i,j in self.dict1.items():
        flag1=self.clr in i
        flag2=other.clr in i
        if flag1==True and flag2==True:
          return Color(j)
C1 = Color(input("First Color: ").lower())
C2 = Color(input("Second Color: ").lower())
C3 = C1 + C2
print("Color formed:", C3.clr)
# Out:
# First Color: yellow
# Second Color: BLUE
# Color formed: Green

# %%
#8
class Coordinates:
  def __init__(self,x,y):
    self.x=x
    self.y=y
  def __sub__(self,other):
    return Coordinates(self.x-other.x,self.y-other.y)

# %%
#5
class
